# %% [markdown]
# # Web Scraping
# Scraping is simply a process of extracting (from various means), copying and screening of data. Web scraping provides a way to the developers to collect and analyze data from the internet.
#
# Web-scraping provides one of the great tools to automate most of the things a human does while browsing.
#
# In this project we will explore "How to extract information from the popular Good Reads platform to analyze and generate interesting insights around Book Trends"
#
# Goodreads is one the world’s largest community for reviewing and recommending books. It's a favorite platform for many a voracious readers!!

# %% [markdown]
# This project is partly inspired by following linked project. [Reference link :](https://medium.com/@soodakriti175/goodreads-web-scraping-92345b620f9c)
#
# I have structured this first python notebook detailing below tasks:
#
# 1.   How to scrape certain sections of a page using Beautiful Soup? In particular, all books listed under a Good Reads user defined list in a given page.
# 2.   How to iteratively scrape all pages to obtain specific attributes on all books related information belonging to a particular list?
# 3. How to load the scraped contents into a Pandas dataframe?
# 4. How to expand the scope and iteratively scrape all lists for books related information for a list of user defined tags and append the extracted info to an existing .csv file loaded in Google Drive? Example: Tags such as "fiction", "science-fiction" etc.

# %% [markdown]
# # Install the required libraries

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests) (1.26.15)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4) (2.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)

# %% [markdown]
# # Import drive library and mount google drive path to access files stored in the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Change to working directory

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %% [markdown]
# Command to read and load a given file to a dataframe.

# %%
df = pd.read_csv("/content/drive/My Drive/goodreads.csv", delim_whitespace=True)

# %% [markdown]
# # ***Section 1***
# How to scrape certain sections of a page using Beautiful Soup? In particular, all books listed under a Good Reads user defined list in a given page.

# %% [markdown]
# Import "get" method from python requests module.
# Below is a sample command to fetch contents of a URL from GoodReads platform.
# Note: Below URL fetches contents of the first page of the list **"12362.All_Time_Favorite_Romance_Novels"  **

# %%
from requests import get
url = 'https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=1'
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage
# ">
# <head>
#   <title>All Time Favorite Romance Novels (5132 books)</title>
#
# <meta content='5,111 books based on 12317 votes: Pride and Prejudice by Jane Austen, Fifty Shades of Grey by E.L. James, Beautiful Disaster by Jamie McGuire, Twilight b...' name='description'>
# <meta content='telephone=no' name='format-detection'>
# <link href='https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels' rel='canonical'>
#
#
#
#     <sc

# %% [markdown]
# # Beautiful Soup - An Overview
#
# The Beautiful Soup is a python library which is named after a Lewis Carroll poem of the same name in “Alice’s Adventures in the Wonderland”. Beautiful Soup is a python package and as the name suggests, parses the unwanted data and helps to organize and format the messy web data by fixing bad HTML and present to us in an easily-traversible XML structures.
#
# In short, Beautiful Soup is a python package which allows us to pull data out of HTML and XML documents.
#
# [Click for more info:](https://www.tutorialspoint.com/beautiful_soup/beautiful_soup_quick_guide.htm)

# %% [markdown]
# Below section used find_all method to extract all <tr> tags of itemtype "http://schema.org/Book". This information on which tag to parse to extract relevant book containers was obtained by right clicking on [this page](https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels) and choosing inspect option.

# %%
response = requests.get(url)
html = response.content
html_soup = bs(html, 'html.parser')
book_containers = html_soup.find_all('tr',itemtype="http://schema.org/Book")
print(type(book_containers))
print(len(book_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 100

# %% [markdown]
# Below section extracts and prints the **html content** of a single book container.

# %%
first_book = book_containers[0]
first_book
# Out:
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">1</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="1885"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="1885" data-resource-type="Book">
# <a href="/book/show/1885.Pride_and_Prejudice" title="Pride and Prejudice">
# <img alt="Pride and Prejudice" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1320399351i/1885._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/1885.Pride_and_Prejudice" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Pride and Prejudice</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/1265.Jane_Austen" itemprop="url"><span itemprop="name">Jane Austen</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.28 avg rating — 3,899,092 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 237,502</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_820690" onclick="new Ajax.Request('/list/list_book/872724', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_820690');$('loading_link_820690').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_820690').show();;Element.hide('loading_anim_820690');}, onLoading:function(request){;Element.show('loading_anim_820690');Element.hide('loading_link_820690')}, onSuccess:function(request){Element.hide('loading_anim_820690');Element.show('loading_link_820690');}, parameters:'authenticity_token=' + encodeURIComponent('f00EvovZhdmq4f6oDVXvdyJp9YeDZy+9/II2jvnrUQ9d5GyR2QE9mptj3/4UNcsA3iAl3diXlbQqt7Xnpag75g==')}); return false;">2,403 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_820690" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="1_book_1885">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ezXNK+kxQE18x71gupeFsIcVoAP6338K0LcCqV9jo1tZnKUEu+n4Dk1FnDaj96HHe1xwWaEvxQMGgoHAAyDJsg=="/>
# <input id="book_id" name="book_id" type="hidden" value="1885"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_1885"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="KIN0Ex7b/hQlxuwkVl9p1DC1IoNvoBlS9IrttU5rimAKKhw8TANGVxREzXJPP02jzPzy2TRQo1siv27cEijgiQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_1885"/>
# <input id="book_id" name="book_id" type="hidden" value="1885"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# <div class="wtrShelfMenu">
# <ul class="wtrExclusiveShelves">
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
# <span class="progressTrigger">Want to Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
# <span class="progressTrigger">Currently Reading</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="read">
# <span class="progressTrigger">Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="1885" data-restore-rating="null" data-submit-url="/review/rate/1885?stars_click=true&amp;wtr_button_id=1_book_1885" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>

# %% [markdown]
# Next we see how to extract the entire "a" tag belonging to the class "bookTitle" for the first book.

# %%
name = first_book.find('a',class_="bookTitle")
name
# Out:
# <a class="bookTitle" href="/book/show/1885.Pride_and_Prejudice" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Pride and Prejudice</span>
# </a>

# %% [markdown]
# We then use the strip() method to extract specific details like the **Book Title**, **AuthorName**, **Scoring** and **Ratings** etc.

# %%
name = first_book.find('a',class_="bookTitle").text.strip()
name
# Out:
# 'Pride and Prejudice'

# %%
authors = first_book.find('a',class_="authorName").text.strip()
authors
# Out:
# 'Jane Austen'

# %%
scoring = first_book.find('span',class_="greyText smallText uitext").text.strip().split()
scoring
# Out:
# ['4.28', 'avg', 'rating', '—', '3,899,092', 'ratings']

# %%
avg_scores=scoring[0]
rates = scoring[4]
print("average scores:",avg_scores)
print("ratings", rates)
# Out:
# average scores: 4.28
# ratings 3,899,092

# %%
scores_and_votes = first_book.find('span',class_="smallText uitext").text.strip().split()
scores_and_votes
# Out:
# ['score:', '237,502,', 'and', '2,403', 'people', 'voted']

# %% [markdown]
# **PLEASE NOTE**: A book’s total score is based on multiple factors, including the number of people who have voted for it and how highly those voters ranked the book.

# %%
scores = scores_and_votes[1]
votes = scores_and_votes[3]
print("scores:", scores)
print("votes:", votes)
# Out:
# scores: 237,502,
# votes: 2,403

# %% [markdown]
# # Section 2
#
# How to iteratively scrape all pages to obtain all books related information belonging to a particular list?
#
# Below piece iterates through all the pages of a given list and constructs and prints a valid URL to retrieve the page content from. Here we have hardcoded the total number of pages as 53( at the time of retrieval ).

# %%
page = 1
while page != 53:
      url = f"https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page={page}"
      print(url)
      page = page + 1
# Out:
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=1
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=2
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=3
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=4
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=5
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=6
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=7
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=8
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=9
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=10
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=11
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=12
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=13
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=14
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=15
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=16
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=17
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=18
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=19
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=20
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=21
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=22
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=23
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=24
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=25
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=26
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=27
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=28
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=29
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=30
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=31
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=32
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=33
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=34
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=35
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=36
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=37
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=38
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=39
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=40
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=41
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=42
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=43
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=44
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=45
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=46
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=47
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=48
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=49
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=50
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=51
# https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page=52

# %% [markdown]
# Combining all the pieces of code we have seen so far, we see a sample on how to extract all books related info from all pages for a specific Book List, eg: "https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels"
# Please note that we have still hardcoded both the list url and the total number of pages in this sample.

# %%
from requests import get
page = 1
names = []
ratings = []
avgscores = []
author=[]
score=[]
votes=[]
while page != 53:
      url = f"https://www.goodreads.com/list/show/12362.All_Time_Favorite_Romance_Novels?page={page}"
      #print(url)
      response = get(url)
      html = response.content
      html_soup = bs(html, 'html.parser')
      book_containers = html_soup.find_all('tr',itemtype="http://schema.org/Book")
      #print(book_containers[0])
      for container in book_containers:
        #print(container)
        if container.find('td', width='100%') is not None:
          book = container.find('td', width='100%')
          #print(book)
          name = book.find('a',class_="bookTitle").text.strip()
          #print(name)
          names.append(name)
          authors = book.find('a',class_="authorName").text.strip()
          author.append(authors)
          scoring = book.find('span',class_="greyText smallText uitext").text.strip().split()
          avg_score = scoring[0]
          rating = scoring[4]
          avgscores.append(avg_score)
          ratings.append(rating)
          scoring_and_rating = book.find('span',class_="smallText uitext").text.strip().split()
          #print(scoring_and_rating)
          scores = scoring_and_rating[1]
          score.append(scores)
          voted = scoring_and_rating[3]
          votes.append(voted)
      page = page + 1

# %% [markdown]
# # Section 3
#
# How to load the scraped contents into a Pandas dataframe?
#
# We now see how to create and populate a pandas dataframe with the specific book related information we have scraped for all books in a given list.

# %%
df = pd.DataFrame({'book title': names,
                   'author': author,
                   'avg_score': avg_scores,
                   'rating': ratings,
                   'score': score,
                   'votes': votes,
                   'list': 'All Time Favorite Romance Novels'
})
df
# Out:
#                                    book title           author avg_score  \
# 0                         Pride and Prejudice      Jane Austen      4.28
# 1     Fifty Shades of Grey (Fifty Shades, #1)       E.L. James      4.28
# 2          Beautiful Disaster (Beautiful, #1)    Jamie McGuire      4.28
# 3            Twilight (The Twilight Saga, #1)  Stephenie Meyer      4.28
# 4             The Notebook (The Notebook, #1)  Nicholas Sparks      4.28
# ...                                       ...              ...       ...
# 5026  Kiss Me If You Can (Bachelor Blogs, #1)   Carly Phillips      4.28
# 5027                   The Seer and the Sword  Victoria Hanley      4.28
# 5028                         The Marrying Man  Barbara Bretton      4.28
# 5029    Tied with Me (With Me in Seattle, #6)    Kristen Proby      4.28
# 5030                     Used (Unlovable, #1)    Lynetta Halat      4.28
#
#          rating     score  votes                              list
# 0     3,899,117  237,502,  2,403  All Time Favorite Romance Novels
# 1     2,412,723  231,036,  2,343  All Time Favorite Romance Novels
# 2       643,944  216,772,  2,199  All Time Favorite Romance Novels
# 3     6,107,867  138,962,  1,426  All Time Favorite Romance Novels
# 4     1,584,719   98,597,  1,013  All Time Favorite Romance Novels
# ...         ...       ...    ...                               ...
# 5026      5,274        1,      1  All Time Favorite Romance Novels
# 5027     10,598        1,      1  All Time Favorite Romance Novels
# 5028        121        1,      1  All Time Favorite Romance Novels
# 5029     21,582        1,      1  All Time Favorite Romance Novels
# 5030      2,168        1,      1  All Time Favorite Romance Novels
#
# [5031 rows x 7 columns]

# %% [markdown]
# # Section 4
#
# How to expand the scope and iteratively scrape all lists for books related information for a list of user defined tags and append the extracted info to an existing .csv file loaded in Google Drive? Example: Tags such as "fiction", "science-fiction" etc.
#
# For execution purpose we have limited the value of tags to include only "fiction" and "science-fiction".
# However the scope of the tags can be increased to include more genres such as below
#
# ```
# # tags = ["romance", "fiction", "young-adult", "fantasy", "science-fiction", "non-fiction", "children", "history", "mystery", "covers", "horror", "historical-fiction", "best", "gay", "titles", "paranormal", "love", "middle-grade", "contemporary", "historical-romance", "thriller", "nonfiction", "biography", "women", "series", "lgbt", "queer", "classics", "graphic-novels", "memoir"]
# ```
#
# Also please note how the hardcoding of list URLs and number of pages are eliminated here and are instead derived using below beautiful soup lambda expressions as highlighted below.
#
#
# ```
# html_soup.find_all("a", href=re.compile(f"/list/tag/{tags[i]}?page="))
# all_links = html_soup.find_all("a", href=lambda href: href and f"/list/tag/{tags[i]}?page=" in href)
# ```

# %%
import re
from requests import get
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
names = []
ratings = []
avgscores = []
author=[]
score=[]
votes=[]
baseUrl = f"https://www.goodreads.com"
page = 1
urls = []
dfs = []
#Below line is commented out to indicate how the scope of the tags can be increased to include more genres"
#tags = ["romance", "fiction", "young-adult", "fantasy", "science-fiction", "non-fiction", "children", "history", "mystery", "covers", "horror", "historical-fiction", "best", "gay", "titles", "paranormal", "love", "middle-grade", "contemporary", "historical-romance", "thriller", "nonfiction", "biography", "women", "series", "lgbt", "queer", "classics", "graphic-novels", "memoir"]
tags = ["fiction", "science-fiction"]

listTitles = []
listTitleLinks = []
for tag in tags:
  url = f"https://www.goodreads.com/list/tag/{tag}"
  urls.append(url)

for i in range(len(tags)):
  response = get(urls[i])
  html = response.content
  html_soup = bs(html, 'html.parser')
  
  html_soup.find_all("a", href=re.compile(f"/list/tag/{tags[i]}?page="))
  all_links = html_soup.find_all("a", href=lambda href: href and f"/list/tag/{tags[i]}?page=" in href)
  #print(all_links)
  #extract total number of pages 
  pages = all_links[-2].text.strip()
  print(f"Total pages for {tags[i]} genre is : {pages}")
  page = 1
  while page <= int(pages):
    #print(page)
    for link in all_links:
      currentUrl = baseUrl + link.get('href')
      
      response = get(currentUrl)
      html = response.content
      html_soup = bs(html, 'html.parser')
      listTitles_for_tag = html_soup.find_all("a",class_="listTitle")
      for listTitle in listTitles_for_tag:
        listTitles.append(listTitle.text.strip())
        print(f"Total number of listTiles in genre {tags[i]} are : {len(listTitles_for_tag)}")
        currentLink = baseUrl + listTitle.get('href')
        listTitleLinks.append(currentLink)
        print(f"Fetching content for {currentLink}")

        response = get(currentLink)
        html = response.content
        html_soup = bs(html, 'html.parser')
        html_soup.find_all("a", href=re.compile(f"{listTitle.get('href')}?page="))
        all_links = html_soup.find_all("a", href=lambda href: href and f"{listTitle.get('href')}?page=" in href)
        for j in range(len(all_links)):
          m = re.search(r'\d+$', all_links[j].text.strip())
          if m is None:
            pages_in_listTitle = all_links[j-1].text.strip()
            break
            #pages_in_listTitle = all_links[-2].text.strip()
        print(f"Total pages in {currentLink} : {pages_in_listTitle}")
        currentPage=1
        while currentPage <=int(pages_in_listTitle):
         currentLink = baseUrl + listTitle.get('href')
         currentLink = currentLink + f"?page={currentPage}"
         print(f"Fetching content for {currentLink}")
         response = get(currentLink)
         html = response.content
         html_soup = bs(html, 'html.parser')
         book_containers = html_soup.find_all('tr',itemtype="http://schema.org/Book")
         print(f"Total number of books in {listTitle.text.strip()} are : {len(book_containers)}")
         if len(book_containers) == 0:
           break
         for container in book_containers:
          if container.find('td', width='100%') is not None:
           book = container.find('td', width='100%')
           #print(book)
           name = book.find('a',class_="bookTitle").text.strip()
           #print(name)
           names.append(name)
           authors = book.find('a',class_="authorName").text.strip()
           author.append(authors)
           scoring = book.find('span',class_="greyText smallText uitext").text.strip().split()
           if len(scoring) >=0:
            avg_score = scoring[0]
            avgscores.append(avg_score)
           if len(scoring) >= 4:
            rating = scoring[4]
            ratings.append(rating)
           scoring_and_rating = book.find('span',class_="smallText uitext").text.strip().split()
           #print(scoring_and_rating)
           if len(scoring_and_rating) >=1:
            scores = scoring_and_rating[1]
            score.append(scores)
           if len(scoring_and_rating) >= 3:
            voted = scoring_and_rating[3]
            votes.append(voted)
          else:
            currentPage = currentPage + 1

          #print(f"Book Titles: {names}, Author: {author}, Avg_Score: {avgscores}, Rating: {ratings}, Score: {score}, Votes: {votes}, ListTitle: {listTitle}, Genre: {tags[0]}")  
          a = {"book title": names, "author": author, "avg_score": avgscores, "rating": ratings, "score": score, "votes": votes, "list title": listTitle.text.strip() }
          df = pd.DataFrame.from_dict(a, orient='index')
          df = df.transpose()
          for index, row in df.iterrows():
            df.at[index, 'list title'] = listTitle.text.strip()
            df.at[index, 'genre'] = tags[i]
         print("Appending the dataframe to file: goodreads_fiction_types.csv") 
         df.to_csv('/content/drive/My Drive/goodreads_fiction_types.csv', mode='a', index=False, header=False) 
         names = []
         ratings = []
         avgscores = []
         author=[]
         score=[]
         votes=[]
         currentPage = currentPage + 1
      page = page + 1
# Out:
# Total pages for fiction genre is : 100
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die
# Total pages in https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die : 14
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=1
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=2
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=3
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=4
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=5
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=6
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=7
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=8
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=9
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=10
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=11
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=12
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=13
# Total number of books in 1001 Books You Must Read Before You Die are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/952.1001_Books_You_Must_Read_Before_You_Die?page=14
# Total number of books in 1001 Books You Must Read Before You Die are : 18
# Appending the dataframe to file: goodreads_fiction_types.csv
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters
# Total pages in https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters : 48
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=1
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=2
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=3
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=4
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=5
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=6
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=7
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=8
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=9
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=10
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=11
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=12
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=13
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=14
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=15
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=16
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=17
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=18
# Total number of books in Best Female Lead Characters are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/2602.Best_Female_Lead_Characters?page=19
# Total number of books in Best Female Lead Characters are : 0
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read
# Total pages in https://www.goodreads.com/list/show/7663.New_Authors_to_Read : 44
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=1
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=2
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=3
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=4
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=5
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=6
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=7
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=8
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=9
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=10
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=11
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=12
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=13
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=14
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=15
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=16
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=17
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=18
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=19
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=20
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=21
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=22
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=23
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=24
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=25
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=26
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=27
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=28
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=29
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=30
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=31
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=32
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=33
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=34
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=35
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=36
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=37
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=38
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=39
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=40
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=41
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=42
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=43
# Total number of books in New Authors to Read are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7663.New_Authors_to_Read?page=44
# Total number of books in New Authors to Read are : 33
# Appending the dataframe to file: goodreads_fiction_types.csv
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero
# Total pages in https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero : 35
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=1
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=2
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=3
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=4
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=5
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=6
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=7
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=8
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=9
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=10
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=11
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=12
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=13
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=14
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=15
# Total number of books in So you love a Bad Boy or Tortured Hero are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/4243.So_you_love_a_Bad_Boy_or_Tortured_Hero?page=16
# Total number of books in So you love a Bad Boy or Tortured Hero are : 0
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018
# Total pages in https://www.goodreads.com/list/show/74439.YA_Novels_of_2018 : 11
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=1
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=2
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=3
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=4
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=5
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=6
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=7
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=8
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=9
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=10
# Total number of books in YA Novels of 2018 are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/74439.YA_Novels_of_2018?page=11
# Total number of books in YA Novels of 2018 are : 20
# Appending the dataframe to file: goodreads_fiction_types.csv
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors
# Total pages in https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors : 64
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=1
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=2
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=3
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=4
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=5
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=6
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=7
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=8
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=9
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=10
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=11
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=12
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=13
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=14
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=15
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=16
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=17
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=18
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=19
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=20
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=21
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=22
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=23
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=24
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=25
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=26
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=27
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=28
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=29
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=30
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=31
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=32
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=33
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=34
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=35
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=36
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=37
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=38
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=39
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=40
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=41
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=42
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=43
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=44
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=45
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=46
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=47
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=48
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=49
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=50
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=51
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=52
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=53
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=54
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=55
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=56
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=57
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=58
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=59
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=60
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=61
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=62
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=63
# Total number of books in Best of Little-Known Authors are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/7205.Best_of_Little_Known_Authors?page=64
# Total number of books in Best of Little-Known Authors are : 94
# Appending the dataframe to file: goodreads_fiction_types.csv
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_
# Total pages in https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_ : 42
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=1
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=2
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=3
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=4
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=5
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=6
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=7
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=8
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=9
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=10
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=11
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=12
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=13
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=14
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=15
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=16
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=17
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=18
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=19
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=20
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=21
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=22
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=23
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=24
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=25
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=26
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=27
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=28
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=29
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=30
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=31
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=32
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=33
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=34
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=35
# Total number of books in Thrillers You Must Read! are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/8306.Thrillers_You_Must_Read_?page=36
# Total number of books in Thrillers You Must Read! are : 0
# Total number of listTiles in genre fiction are : 30
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books
# Total pages in https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books : 76
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=1
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=2
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=3
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=4
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=5
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=6
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=7
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=8
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=9
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=10
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=11
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=12
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=13
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=14
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=15
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=16
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=17
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=18
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=19
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=20
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=21
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=22
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=23
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=24
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=25
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=26
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=27
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=28
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=29
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=30
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=31
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=32
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=33
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=34
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=35
# Total number of books in Best Woman-Authored Books are : 100
# Appending the dataframe to file: goodreads_fiction_types.csv
# Fetching content for https://www.goodreads.com/list/show/26495.Best_Woman_Authored_Books?page=36
